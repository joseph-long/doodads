# %%
import doodads as dd

# %%
n_orbits = 10

# %%
true_r, proj_xy = dd.generate_random_orbit_positions(n_orbits, 1 * u.Msun, 1 * u.M_e, fixed_sma=1*u.AU)
plt.scatter(proj_xy[:,0], proj_xy[:,1])

# %%
all_true_r, all_proj_xy = dd.generate_random_orbit_positions(n_orbits, 1 * u.Msun, 1 * u.M_e, draw_sma=False, fixed_sma=1*u.AU, epochs=np.linspace(0, 1) * u.year)
for i in range(n_orbits):
    plt.plot(all_proj_xy[:, i, 0], all_proj_xy[:, i, 1])
plt.gca().set(xlim=(-1.5, 1.5), ylim=(-1.5, 1.5), aspect='equal')
# Out:
# [(-1.5, 1.5), (-1.5, 1.5), None]
