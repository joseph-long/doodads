# %%
cont = dd.spectra.TableSpectrum(
    'https://magao-x.org/docs/handbook/_static/ref/filters/magaox_sci1-halpha-cont_bs-halpha-ir_scibs-halpha.dat',
    wavelength_units=u.m,
    value_units=u.dimensionless_unscaled,
)

# %%
dd.H_ALPHA.display()
cont.display()
# Out:
# <Axes: xlabel='Wavelength [m]', ylabel='Transmission'>

# %%
atm = dd.LA_SILLA_ATMOSPHERES.get(airmass=1, pwv=0.5*u.mm)

# %%
dd.H_ALPHA.multiply(atm).display()
dd.H_ALPHA.display()
cont.display()
cont.multiply(atm).display()
plt.xlim(655*u.nm, 675*u.nm)
# Out:
# (655.0, 675.0)
