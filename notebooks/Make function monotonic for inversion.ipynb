# %%
import numpy as np
import matplotlib.pyplot as plt
import doodads as dd

# %%
xs = np.linspace(0, 3, num=50)
ys = np.sin(xs*4) + xs

plt.plot(xs, ys)

# %%
new_xs, new_ys, excluded_ranges = dd.math.make_monotonic_increasing(xs, ys, display=False)

# %%
new_xs, new_ys, excluded_ranges = dd.math.make_monotonic_increasing(xs, ys, display=True)
print(excluded_ranges)
# Out:
# [ExcludedRange(min_x=0.42857142857142855, max_x=1.5918367346938775, extremum_y=0.1479616372282465), ExcludedRange(min_x=2.020408163265306, max_x=3.0, extremum_y=1.7179940886079117)]

# %%
new_xs, new_ys, excluded_ranges = dd.math.make_monotonic_decreasing(xs, -ys, display=True)
print(excluded_ranges)
# Out:
# [ExcludedRange(min_x=0.42857142857142855, max_x=1.5918367346938775, extremum_y=-0.1479616372282465), ExcludedRange(min_x=2.020408163265306, max_x=3.0, extremum_y=-1.7179940886079117)]
